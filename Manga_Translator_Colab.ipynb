# %% [markdown]
# <a href="https://colab.research.google.com/github/Nader-Geek/AI_Manga_Reader/blob/main/Manga_Translator_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # مترجم خودکار مانگا / مانهوا به فارسی
#
# OCR → پاک‌سازی حباب → ترجمه با Gemini → رندر فارسی
#
# **ترتیب:** سلول‌ها را از بالا به پایین با Shift+Enter اجرا کنید.
#
# قبل از شروع: `Runtime → Change runtime type → GPU (T4)`

# %%
# !git clone https://github.com/amirwolf5122/Manga-AutoTranslate.git
# !cd Manga-AutoTranslate && mv * ../
# !rm -rf Manga-AutoTranslate
# Out:
# Cloning into 'Manga-AutoTranslate'...
# remote: Enumerating objects: 900, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 900 (delta 252), reused 152 (delta 152), pack-reused 618 (from 3)
# Receiving objects: 100% (900/900), 7.99 MiB | 7.33 MiB/s, done.
# Resolving deltas: 100% (467/467), done.

# %%
# !bash manga.sh
# Out:
#   ============================================
#      Manga Translator
#   ============================================
#
#     [1] Web    - browser interface (no display detected - App hidden)
#     [2] CLI    - asks for input in terminal
#     [3] Exit
#
#   Choose [1/2/3]: 1
# [i] Checking dependencies (first run may take a while)...
# [*] بررسی فونت‌های لحن…
#   ⬇ Vazirmatn-Bold.ttf (کودک — متن عادی حباب) ...
#   ✔ Vazirmatn-Bold.ttf
#   ⬇ Vazirmatn-Regular.ttf (متن بیرون حباب) ...
#   ✔ Vazirmatn-Regular.ttf
#   ⬇ Gandom.ttf (داد کمدی) ...
#   ✔ Gandom.ttf
#   ⬇ Nahid.ttf (زمزمه دست‌نویس) ...
#   ✔ Nahid.ttf
#   ⬇ Samim-Bold.ttf (تفکر ابری) ...
#   ✔ Samim-Bold.ttf
#   ⬇ Sahel-Bold.ttf (UI سیستم/تگ) ...
#   ✔ Sahel-Bold.ttf
#   ⬇ Amiri-Regular.ttf (نامه/طومار) ...
#   ✔ Amiri-Regular.ttf
#   ⬇ Shabnam-Bold.ttf (راوی مستطیل) ...
#   ✔ Shabnam-Bold.ttf
# [+] 8 فونت دانلود شد.
# [*] فونت اصلی: /content/fonts/Amiri-Regular.ttf
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://12b187f2cb28160545.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 21.4 MB/s eta 0:00:00
